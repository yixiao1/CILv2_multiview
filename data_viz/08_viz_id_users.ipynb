# %% [markdown]
# # Visualize the class IDs of the gaze of users/model

# %%
# Dataset is in `f'id_viz_data/id_visibility_data_{AttLoss/Vanilla}_D{num_driver:03d}'.pkl`
# So let's open a pkl file and see what's inside

import pickle
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os

# Load the data
filename = 'id_viz_data/id_visibility_data_AttLoss_D004.pkl'

with open(filename, 'rb') as f:
    data = pickle.load(f)

# Let's see what's inside
print(data.keys())
# Out:
# dict_keys(['59755', '65387', '62315', '11713', '40350', '34459', '51327', '34716', '63851', '63339', '64363', '62827', '64875', '23964', '39579', '38814', '51144', '40859', '40862', '62066', '38300', '53193', '17780', '62322', '61810', '38812', '33948', '24988', '36033', '38081', '37825', '20671', '37569', '64626', '58219', '32961', '43421', '43675', '32449', '44189', '43163', '52937', '33473', '57544', '43457', '50113', '26761', '11457', '39838', '29889', '34204', '38555', '58056', '25244', '04460', '53375', '56191', '52863', '19649', '05996', '05484', '43969', '23945', '33993', '35455', '35967', '38337', '29377', '49601', '46785', '57800', '57537', '27017', '27529', '34943', '14955', '34431', '34203', '38271', '41371', '52417', '48321', '45761', '30601', '47467', '51905', '49089', '51137', '49352', '13249', '40091', '28041', '39326', '30089', '41374', '63644', '47553', '25225', '42910', '52929', '14273', '14783', '42398', '54209', '00157', '00669', '33225', '41886', '26505', '46273
# ...
